# %% [markdown]
# # **1-Dataset Analysis:**

# %% [markdown]
# ## *i) Cleaning Dataset:* <br />
#    Jan 23 Last edits

# %% [markdown]
# Latest check 30th of Jan. 2023 at 5:00PM

# %% [markdown]
# ### **Importings:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from datetime import datetime 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from ast import literal_eval
import datetime

# %%
current_month = datetime.datetime.now().strftime('%B')
data= pd.read_csv(f"../data/raw/anime_mal_{current_month}.csv")


print(data.shape)
data.head(5)
# Out:
# (25019, 33)
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2027746
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1660751
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1480545
# 3      9253                         Steins;Gate     tv   9.07    1341837
# 4     28851                      Koe no Katachi  movie   8.94    1531345
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#    broadcast_day                                       genres  \
# 0         sunday  ['Action', 'Adventure', 'Drama', 'Fantasy']
# 1         sunday           ['Action', 'Adventure', 'Fantasy']
# 2         monday                          ['Action', 'Drama']
# 3      wednesday              ['Drama', 'Sci-Fi', 'Suspense']
# 4            NaN                   ['Award Winning', 'Drama']
#
#                              themes demographics              studios  \
# 0                      ['Military']  ['Shounen']            ['Bones']
# 1                                []  ['Shounen']         ['Madhouse']
# 2  ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 3  ['Psychological', 'Time Travel']           []        ['White Fox']
# 4              ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['anime_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes',
#        'start_date', 'end_date', 'source', 'members', 'favorites',
#        'episode_duration', 'total_duration', 'rating', 'sfw', 'approved',
#        'created_at', 'updated_at', 'start_year', 'start_season',
#        'real_start_date', 'real_end_date', 'broadcast_day', 'genres', 'themes',
#        'demographics', 'studios', 'synopsis', 'main_picture', 'title_english',
#        'title_japanese', 'title_synonyms'],
#       dtype='object')

# %% [markdown]
# ### Taking care of nulls and drops:

# %%
# drops=["broadcast_day_of_the_week","broadcast_start_time","alternative_titles_en","alternative_titles_ja","alternative_titles_synonyms"]
# # data['fav_percent'] = data['num_favorites'] / data['num_list_users']
# data=data.drop(drops,axis=1)[['id','title','type','mean','num_scoring_users','num_episodes',"source",'popularity','fav_percent','rank','rating',"genres","studios",'synopsis',"nsfw"]]

# %%
data.isnull().sum()
# Out:
# anime_id                0
# title                   0
# type                   68
# score                9191
# scored_by               0
# status                  0
# episodes              577
# start_date            910
# end_date             2835
# source               3671
# members                 0
# favorites               0
# episode_duration      623
# total_duration        873
# rating                656
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           4864
# start_season         4864
# real_start_date       910
# real_end_date        2835
# broadcast_day       21592
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# synopsis             4541
# main_picture          189
# title_english       14650
# title_japanese        130
# title_synonyms          0
# dtype: int64

# %%
df = data[data.synopsis.isna()]

# %%
(df.groupby('type')['type'].count()/data.groupby('type')['type'].count()).plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
(df.groupby('source')['source'].count()/data.groupby('source')['source'].count()).plot(kind='bar')
# Out:
# <Axes: xlabel='source'>

# %%
(df.groupby('rating')['rating'].count()/data.groupby('rating')['rating'].count()).plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %%
(df.groupby('sfw')['sfw'].count()/data.groupby('sfw')['sfw'].count()).plot(kind='bar')
# Out:
# <Axes: xlabel='sfw'>

# %%
def fill_na(df,col):
    index = df[df[col].isna()].index
    value = np.abs(np.random.normal(loc=df[col].mean(), scale=df[col].std(), size=df[col].isna().sum()))
    df[col] = df[col].fillna(pd.Series(value, index=index))

# %%
# fill_na(data,'mean')
fill_na(data,'score')
#data['fav_percent'] = data['fav_percent'].fillna(value=round(data['fav_percent'].mean(),3))
#data['num_episodes'] = data['num_episodes'].fillna(value=round(data['num_episodes'].mean()))
data['source'] = data['source'].fillna(value=data['source'].mode()[0])
data['rating'] = data['rating'].fillna(value=data['rating'].mode()[0])
data['synopsis'] = data['synopsis'].fillna('')

# %%
data.isnull().sum()
# Out:
# anime_id                0
# title                   0
# type                   68
# score                   0
# scored_by               0
# status                  0
# episodes              577
# start_date            910
# end_date             2835
# source                  0
# members                 0
# favorites               0
# episode_duration      623
# total_duration        873
# rating                  0
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           4864
# start_season         4864
# real_start_date       910
# real_end_date        2835
# broadcast_day       21592
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# synopsis                0
# main_picture          189
# title_english       14650
# title_japanese        130
# title_synonyms          0
# dtype: int64

# %%
data.nunique()
# Out:
# anime_id            25019
# title               25009
# type                    6
# score                9758
# scored_by            8408
# status                  3
# episodes              251
# start_date           8437
# end_date             8264
# source                 16
# members             11095
# favorites            1816
# episode_duration     2978
# total_duration       5450
# rating                  6
# sfw                     2
# approved                2
# created_at          25019
# updated_at          24991
# start_year            101
# start_season            4
# real_start_date      8703
# real_end_date        8477
# broadcast_day           8
# genres               1005
# themes                838
# demographics            9
# studios              1565
# synopsis            20236
# main_picture        24830
# title_english       10175
# title_japanese      23900
# title_synonyms      12243
# dtype: int64

# %%
data.columns
# Out:
# Index(['anime_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes',
#        'start_date', 'end_date', 'source', 'members', 'favorites',
#        'episode_duration', 'total_duration', 'rating', 'sfw', 'approved',
#        'created_at', 'updated_at', 'start_year', 'start_season',
#        'real_start_date', 'real_end_date', 'broadcast_day', 'genres', 'themes',
#        'demographics', 'studios', 'synopsis', 'main_picture', 'title_english',
#        'title_japanese', 'title_synonyms'],
#       dtype='object')

# %% [markdown]
# ## Preprocessing:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from tqdm.notebook import tqdm
import ast
import re
import spacy as sp
from keybert import KeyBERT
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 5
#       3 import ast
#       4 import re
# ----> 5 import spacy as sp
#       6 from keybert import KeyBERT
#       7 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ModuleNotFoundError: No module named 'spacy'

# %%
data.title.head(10)
# Out:
# 0        Fullmetal Alchemist: Brotherhood
# 1                  Hunter x Hunter (2011)
# 2      Shingeki no Kyojin Season 3 Part 2
# 3                             Steins;Gate
# 4                          Koe no Katachi
# 5                          Kimi no Na wa.
# 6      Code Geass: Hangyaku no Lelouch R2
# 7    Shingeki no Kyojin: The Final Season
# 8           Sen to Chihiro no Kamikakushi
# 9         Code Geass: Hangyaku no Lelouch
# Name: title, dtype: object

# %% [markdown]
# ## *ii)EDA:*

# %%
data.columns
# Out:
# Index(['anime_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes',
#        'start_date', 'end_date', 'source', 'members', 'favorites',
#        'episode_duration', 'total_duration', 'rating', 'sfw', 'approved',
#        'created_at', 'updated_at', 'start_year', 'start_season',
#        'real_start_date', 'real_end_date', 'broadcast_day', 'genres', 'themes',
#        'demographics', 'studios', 'synopsis', 'main_picture', 'title_english',
#        'title_japanese', 'title_synonyms'],
#       dtype='object')

# %%
sns.set_style("dark")
plt.figure(figsize=(12,6))
plt.hist(data['score'], bins=100)
plt.show()

# %%
fig = px.pie(data, 'type')
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# *Notes:* Naturally TV has higher percentage as anime media.

# %%
corr = data.corr()

# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(20, 14))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# C:\Users\Lord MZ\AppData\Local\Temp\ipykernel_23872\2559744040.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %% [markdown]
# *Notes:*  So, basically interesting factors that are affecting the mean factor are : rank, popularity, num_scoring_users, ignore num_list_users for now till further investigation of difference.

# %%
fig = px.histogram(data[pd.to_datetime(data['start_date']).dt.year >= 1980], x='start_date', color='type')
fig.update_layout(bargap=0.1)

# %% [markdown]
# *Notes:* Obviously 2016 was a good year for Otakus :3 specially summer-Autumn-Fall seasons, with 119 tv, 45 movie, 23 ova, 61 ona, 60 special and 41 music. (Gotta check watching list lmao).

# %%
data.groupby('episodes')['anime_id'].count().sort_values(ascending=False).head(30).plot(kind='bar', figsize=(8,6))
plt.show()

# %% [markdown]
# *Notes:* A lot of Movies (1 episode) that's why the spike, but the summation of all others are the other percentages of tv,ova,ona,... etc. most tv/specials are short 12 (episodes)/(season|title). </br>
# *The fans of "When you have eliminated the impossible" teenager for 22+ years don't give up :(* </br>
# *Gomu Gomu no guys don't be Sadge :(*

# %%
# #data[['title','fav_percent']].sort_values(by=['fav_percent'],ascending=False).head(30).plot(kind='bar', figsize=(15,10))
# data.sort_values(by=['fav_percent'],ascending=False)[1:21].plot(kind='bar',x='title',y='fav_percent');

# %% [markdown]
# One Piece in the top as expected

# %% [markdown]
# ###  NLP Pre-processing

# %% [markdown]
# ### Synopsis Keyword Analysis:
# *(NLP)* :
# * KeyBERT.
# * Spacy.

# %% [markdown]
# * Creating clean text, nouns and keywords from synopsis.
# * Separate in new df for data analysis.
# * Delete Syns entries from main df.

# %%
NLP = sp.load("en_core_web_lg")
TITLE = 'Death Note'
key_model = KeyBERT()
data = data[~data.title.duplicated(keep='first')]
text = data[data['title'] == TITLE].synopsis.values[0]
def clean_text(text):
    text = re.sub("[\(\[].*?[\)\]]", "", text)
    text = text.replace('\n', "").replace('\r', "")
    text = text.replace('', "")
    text = re.sub('[^a-zA-Z]', " ", str(text))
    text = ' '.join(text.split())
    text = text.lower()
    doc = NLP(text)
    return doc

doc = clean_text(text)
print(doc)
# Out:
# brutal murders petty thefts and senseless violence pollute the human world in contrast the realm of death gods is a humdrum unchanging gambling den the ingenious year old japanese student light yagami and sadistic god of death ryuk share one belief their worlds are rotten for his own amusement ryuk drops his death note into the human world light stumbles upon it deeming the first of its rules ridiculous the human whose name is written in this note shall die however the temptation is too great and light experiments by writing a felon s name which disturbingly enacts his first murder aware of the terrifying godlike power that has fallen into his hands light under the alias kira follows his wicked sense of justice with the ultimate goal of cleansing the world of all evil doers the meticulous mastermind detective l is already on his trail but as light s brilliance rivals l s the grand chase for kira turns into an intense battle of wits that can only end when one of them is dead

# %%
data.loc[:,'cleaned_syn'] = data.loc[:,'synopsis'].astype(str).apply(clean_text)

# %%
data.columns
# Out:
# Index(['id', 'title', 'media_type', 'mean', 'num_scoring_users',
#        'num_episodes', 'source', 'popularity', 'fav_percent', 'rank', 'rating',
#        'genres', 'studios', 'synopsis', 'nsfw', 'cleaned_syn'],
#       dtype='object')

# %%
df_string=data[['title','synopsis','cleaned_syn']]

# %%
df_num=pd.get_dummies(data[["type","source","nsfw","genres","rating","studios"]], columns=["type","source","nsfw","genres","rating","studios"], prefix=["type","source","nsfw","genres","rating","studios"])
df_num[['id','mean','num_scoring_users','num_episodes','popularity','fav_percent','rank']]=data[['id','mean','num_scoring_users','num_episodes','popularity','fav_percent','rank']]

# %%
# Based on https://stackoverflow.com/questions/48925328/how-to-get-all-noun-phrases-in-spacy
def get_candidates(doc):
    # code to recursively combine nouns
    # 'We' is actually a pronoun but included in your question
    # hence the token.pos_ == "PRON" part in the last if statement
    # suggest you extract PRON separately like the noun-chunks above

    index = 0
    noun_indices = [i for i, token in enumerate(doc) if token.pos_ == 'NOUN']
    candidates = []
    for idxValue in noun_indices:
        start = doc[idxValue].left_edge.i if not bool(doc[idxValue].left_edge.ent_type_) else idxValue
        finish = doc[idxValue].right_edge.i+1 if not bool(doc[idxValue].right_edge.ent_type_) else idxValue + 1
        if 0 < finish-start < 7:
            span = doc[start:finish]
            candidates.append(span.text)
    return candidates

candidates = get_candidates(doc)
print(candidates)
# Out:
# ['brutal murders', 'petty thefts and senseless violence', 'senseless violence', 'the human world', 'contrast', 'the realm of death gods', 'death', 'death gods', 'gambling', 'a humdrum unchanging gambling den', 'ingenious year', 'student', 'light', 'sadistic god', 'their worlds', 'amusement', 'death', 'his death note', 'human world', 'the human world light', 'its rules', 'whose name', 'this note', 'the temptation', 'too great and light experiments', 'a felon s', 'a felon s name', 'his first murder', 'the terrifying godlike power', 'his hands', 'light', 'his wicked sense of justice', 'justice', 'the world of all evil doers', 'all evil doers', 'mastermind', 'the meticulous mastermind detective l', 'l', 'his trail', 'light s', 'light s brilliance', 'the grand chase', 'wits']

# %% [markdown]
# #### **Applying Key-BERT for Keywords extraction:**

# %%
key_model = KeyBERT()
def get_keywords(doc):
    keywords = key_model.extract_keywords(doc.text,keyphrase_ngram_range=(1, 2), candidates=candidates,stop_words='english', use_mmr=True, diversity=0.7)
    return keywords

# %%
get_keywords(doc)
df_string.loc[:,'nouns'] = df_string.loc[:,'cleaned_syn'].apply(get_candidates)
# Out:
# C:\Users\Lord MZ\AppData\Local\Temp\ipykernel_27104\978663173.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_string.loc[:,'keywords'] = df_string.loc[:,'cleaned_syn'].apply(get_keywords)
# Out:
# C:\Users\Lord MZ\AppData\Local\Temp\ipykernel_27104\3928247378.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_string.sample(20)
# Out:
#                                                    title  \
# 12636                                   Renjian Zui Deyi
# 17354                 Ojarumaru: Wasureta Mori no Hinata
# 4544                               A-Channel: +A-Channel
# 20184                                    Kuaile Xing Mao
# 8508                Dokidoki♡Densetsu: Mahoujin Guruguru
# 6093                Yarichin Kateikyoushi Netori Houkoku
# 9833   Girls & Panzer Movie: Cinematic Concert - Fush...
# 6988              Chuan Shu Zijiu Zhinan: Xian Meng Pian
# 5533                                 Mamono Hunter Youko
# 998                           Isekai Meikyuu de Harem wo
# 939                                   Shuumatsu no Harem
# 11327                             Wakakusa no Yon Shimai
# 15088                        Perrine Monogatari Specials
# 21047          25-bu de Wakaru Tegata Kogitte no Hanashi
# 19022                         Nanaraki: Seven Lucky Gods
# 16531                       Zenryoku Yobikou 5.5 Seminar
# 10934                                             Bibury
# 13766                        Kai: Geoul Hosu-ui Jeonseol
# 2948   Tensei shitara Slime Datta Ken 2nd Season: Kan...
# 14636                                       Atomic World
#
#                                                 synopsis  \
# 12636  Six thousand years later, the once prosperous ...
# 17354                A special of the Ojarumaru series.
# 4544                   Extra specials from the DVD/BDs.
# 20184  This entry encompasses eight seasons of The Ad...
# 8508   Join the new legend of Guruguru, where Nike, t...
# 6093   While being a home tutor to the young Shizuku,...
# 9833   An additional episode of Fushou Akiyama Yukari...
# 6988            Second season of Chuan Shu Zijiu Zhinan.
# 5533   Yohko Mono is a regular girl making her way th...
# 998    One day, high school student Michio Kaga attem...
# 939    Reito Mizuhara is a medical student at the Nat...
# 11327  In the United States, the Civil War has just b...
# 15088  A summary of the full series aired as a TV spe...
# 21047  This is a video that explains the basics of bi...
# 19022
# 16531  A CalorieMate x FROGMAN collaboration in a sch...
# 10934  A promotional video for the anime studio Bibur...
# 13766  An adaptation of Hans Christian Andersen's The...
# 2948   Recap of Tensei Shitara Slime Datta Ken 2nd Se...
# 14636  Yoshiki Imazu's graduation work at Musashino A...
#
#                                              cleaned_syn  \
# 12636  (six, thousand, years, later, the, once, prosp...
# 17354           (a, special, of, the, ojarumaru, series)
# 4544              (extra, specials, from, the, dvd, bds)
# 20184  (this, entry, encompasses, eight, seasons, of,...
# 8508   (join, the, new, legend, of, guruguru, where, ...
# 6093   (while, being, a, home, tutor, to, the, young,...
# 9833   (an, additional, episode, of, fushou, akiyama,...
# 6988     (second, season, of, chuan, shu, zijiu, zhinan)
# 5533   (yohko, mono, is, a, regular, girl, making, he...
# 998    (one, day, high, school, student, michio, kaga...
# 939    (reito, mizuhara, is, a, medical, student, at,...
# 11327  (in, the, united, states, the, civil, war, has...
# 15088  (a, summary, of, the, full, series, aired, as,...
# 21047  (this, is, a, video, that, explains, the, basi...
# 19022                                                 ()
# 16531  (a, caloriemate, x, frogman, collaboration, in...
# 10934  (a, promotional, video, for, the, anime, studi...
# 13766  (an, adaptation, of, hans, christian, andersen...
# 2948   (recap, of, tensei, shitara, slime, datta, ken...
# 14636  (yoshiki, imazu, s, graduation, work, at, musa...
#
#                                                    nouns  \
# 12636  [years, sword, the sword god chao qingqiu, the...
# 17354                [a special of the ojarumaru series]
# 4544   [extra specials from the dvd bds, dvd, the dvd...
# 20184  [this entry, the adventures of star cat series...
# 8508   [guruguru, where nike the reluctant hero, the ...
# 6093   [home, a home tutor, an unusual favor by her f...
# 9833   [an additional episode of fushou akiyama, the ...
# 6988                                            [season]
# 5533   [her way, high school, the earth, demons, the ...
# 998    [day, high school, high school student, the in...
# 939    [cellular sclerosis, order to be treated, cryo...
# 11327  [the civil war, father, daughters, madam, a re...
# 15088               [the full series, tv, a tv specials]
# 21047  [the basics of bills and checks, bills and che...
# 19022                                                 []
# 16531  [x, caloriemate x frogman, school, a school se...
# 10934  [anime, the anime studio, anime, anime directo...
# 13766  [snow, queen in a central asian setting, a cen...
# 2948                                     [recap, season]
# 14636                     [graduation, work, university]
#
#                                                 keywords
# 12636  [(the realm of death gods, 0.3942), (his trail...
# 17354  [(the terrifying godlike power, 0.2065), (a hu...
# 4544   [(the temptation, 0.202), (too great and light...
# 20184  [(ingenious year, 0.0922), (its rules, 0.0395)...
# 8508   [(the realm of death gods, 0.322), (student, 0...
# 6093   [(his death note, 0.1531), (ingenious year, 0....
# 9833   [(senseless violence, 0.2321), (too great and ...
# 6988   [(ingenious year, 0.2193), (its rules, 0.1372)...
# 5533   [(the realm of death gods, 0.2462), (student, ...
# 998    [(gambling, 0.3538), (too great and light expe...
# 939    [(sadistic god, 0.2431), (its rules, 0.0513), ...
# 11327  [(senseless violence, 0.2852), (too great and ...
# 15088  [(the grand chase, 0.2083), (contrast, 0.1466)...
# 21047  [(this note, 0.3215), (its rules, 0.1772), (pe...
# 19022  [(l, 0.5051), (the terrifying godlike power, 0...
# 16531  [(student, 0.3064), (too great and light exper...
# 10934  [(whose name, 0.1688), (too great and light ex...
# 13766  [(the realm of death gods, 0.2206), (student, ...
# 2948   [(ingenious year, 0.2109), (its rules, 0.1582)...
# 14636  [(student, 0.3053), (the realm of death gods, ...

# %%
df_num.shape,df_string.shape
# Out:
# ((23936, 6811), (23936, 3))

# %% [markdown]
#  `df_num` is the Data Frame for the Analytical approach and distance techniques. <br />
#  `df_string` is the textual Data Frame for the NLP approaches to get contextual/semantic content based recommendations.

# %% [markdown]
# # 2- **MODELS TIME:** :3
# ![image info](https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/gettyimages-458406992-1538405221.jpg?crop=0.9xw:0.9xh;0,0&resize=256:*) <br />
#   July's 2022 Work

# %% [markdown]
# ## Similarity Analysis :

# %% [markdown]
# ### Similarity Analysis Using The Numerical Features

# %% [markdown]
# #### Model 1 :  Nearest Neighbors

# %%
from sklearn.neighbors import KDTree
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import BallTree
scaler = StandardScaler()
scaler.fit(df_num.drop(['id'],axis=1).to_numpy())

X = scaler.transform(df_num.drop(['id'],axis=1).to_numpy())

# %%
def get_item_recommendations(anime_title, anime_idx=-1):
    if anime_idx == -1:     
        anime_idx = data[data['title'] == anime_title].index[0]
    return data.iloc[indices[anime_idx][1:]]

# %%
nbrs = NearestNeighbors(n_neighbors=15, algorithm='auto',metric = 'euclidean').fit(X)
_, indices = nbrs.kneighbors(X)

# %%
get_item_recommendations('Sword Art Online')
# Out:
#           id                                              title media_type  \
# 33     21881                                Sword Art Online II         tv
# 4313   53529                  Sword Art Online (Original Movie)      movie
# 30     23755                                  Nanatsu no Taizai         tv
# 70     28121  Dungeon ni Deai wo Motomeru no wa Machigatteir...         tv
# 2697   32561  Hai to Gensou no Grimgar: Furoagari no Kabe ni...    special
# 125    34577            Nanatsu no Taizai: Imashime no Fukkatsu         tv
# 5932   25117  Ryuugajou Nanana no Maizoukin: Nanana Nippon M...    special
# 14528  45595                                       Baten Kaitos      music
# 141    14513                       Magi: The Labyrinth of Magic         tv
# 11193  37908                         Senjou no Valkyria Special    special
# 4783   38958                  Manga de Wakaru! Fate/Grand Order    special
# 5558    7016                 Senjou no Valkyria: SenVal Theater    special
# 195    18115                         Magi: The Kingdom of Magic         tv
# 15813   3073                                   Robby to Kerobby         tv
#
#            mean  num_scoring_users  num_episodes       source  popularity  \
# 33     6.700000            1260784          24.0  light_novel          34
# 4313   6.250559                  0          15.0  light_novel        4314
# 30     7.680000            1263708          24.0        manga          31
# 70     7.550000             893500          13.0  light_novel          71
# 2697   6.590000              28376           1.0  light_novel        2698
# 125    7.600000             658986          24.0        manga         126
# 5932   6.530000               2154           6.0  light_novel        5933
# 14528  6.880000                122          15.0     original       14532
# 141    8.020000             523865          25.0        manga         142
# 11193  5.480000                417           1.0     original       11195
# 4783   7.650000               9134           1.0         game        4784
# 5558   6.780000               4968           9.0         game        5559
# 195    8.220000             435627          25.0        manga         196
# 15813  6.534263                 54          52.0     original       15817
#
#        fav_percent         rank rating  \
# 33        0.004916   5510.00000  pg_13
# 4313      0.001911   2178.34906  pg_13
# 30        0.009870   1196.00000  pg_13
# 70        0.007884   1543.00000  pg_13
# 2697      0.000681   6093.00000  pg_13
# 125       0.003566   1395.00000  pg_13
# 5932      0.000306   6493.00000  pg_13
# 14528     0.002045   4599.00000  pg_13
# 141       0.008994    559.00000  pg_13
# 11193     0.004000  11697.00000  pg_13
# 4783      0.002667   1253.00000  pg_13
# 5558      0.000262   5084.00000  pg_13
# 195       0.009441    318.00000  pg_13
# 15813     0.004000  15812.00000      g
#
#                                                   genres           studios  \
# 33     ['Action', 'Adventure', 'Fantasy', 'Love Polyg...  ['A-1 Pictures']
# 4313   ['Action', 'Adventure', 'Fantasy', 'Love Polyg...                []
# 30         ['Action', 'Adventure', 'Fantasy', 'Shounen']  ['A-1 Pictures']
# 70                    ['Action', 'Adventure', 'Fantasy']     ['J.C.Staff']
# 2697                                          ['Comedy']  ['A-1 Pictures']
# 125        ['Action', 'Adventure', 'Fantasy', 'Shounen']  ['A-1 Pictures']
# 5932                                          ['Comedy']  ['A-1 Pictures']
# 14528                                          ['Music']  ['A-1 Pictures']
# 141        ['Action', 'Adventure', 'Fantasy', 'Shounen']  ['A-1 Pictures']
# 11193                                         ['Comedy']  ['A-1 Pictures']
# 4783                                          ['Comedy']  ['A-1 Pictures']
# 5558                                          ['Comedy']  ['A-1 Pictures']
# 195        ['Action', 'Adventure', 'Fantasy', 'Shounen']  ['A-1 Pictures']
# 15813                                 ['Comedy', 'Kids']  ['A-1 Pictures']
#
#                                                 synopsis   nsfw
# 33     A year after escaping Sword Art Online, Kazuto...  white
# 4313                                                      white
# 30     In a world similar to the European Middle Ages...  white
# 70     Life in the bustling city of Orario is never d...  white
# 2697   OVA episode that will expand on the ending of ...  white
# 125    The fierce battle between Meliodas, the captai...  white
# 5932       Specials included on the Blu-ray/DVD volumes.  white
# 14528  Animated music video project directed by Wabok...  white
# 141    A Magi is a magician whose inclination toward ...  white
# 11193  Fake movie promo video. Included in the DVD vo...  white
# 4783   A short anime based on Manga de Wakaru! Fate/G...  white
# 5558   Special shorts that come with the DVDs for Val...  white
# 195    After celebrating their victory against Al-Tha...  white
# 15813  A story of the adventures of Robby and Kerobby...  white

# %%
nbrs = NearestNeighbors(n_neighbors=15, algorithm='auto',metric = 'hamming').fit(X)
_, indices = nbrs.kneighbors(X)

# %%
get_item_recommendations('Sword Art Online')
# Out:
#          id                                           title media_type  mean  \
# 33    21881                             Sword Art Online II         tv  6.70
# 261   32901                                 Eromanga-sensei         tv  6.37
# 1128  32962                                   Occultic;Nine         tv  6.90
# 606   30727                  Saenai Heroine no Sodatekata ♭         tv  7.77
# 928   21561                   Ryuugajou Nanana no Maizoukin         tv  7.13
# 300   23277                    Saenai Heroine no Sodatekata         tv  7.49
# 477   13659    Ore no Imouto ga Konnani Kawaii Wake ga Nai.         tv  6.94
# 369   14749  Ore no Kanojo to Osananajimi ga Shuraba Sugiru         tv  6.94
# 294   30544                          Gakusen Toshi Asterisk         tv  6.83
# 489   31737               Gakusen Toshi Asterisk 2nd Season         tv  7.01
# 1396  10278                                  The iDOLM@STER         tv  7.61
# 195   18115                      Magi: The Kingdom of Magic         tv  8.22
# 605   19369                                Outbreak Company         tv  7.20
# 68    35790                     Tate no Yuusha no Nariagari         tv  7.99
#
#       num_scoring_users  num_episodes       source  popularity  fav_percent  \
# 33              1260784          24.0  light_novel          34     0.004916
# 261              402679          12.0  light_novel         262     0.003931
# 1128              67930          12.0  light_novel        1129     0.002389
# 606              174901          11.0  light_novel         607     0.004791
# 928               97207          11.0  light_novel         929     0.001530
# 300              295992          12.0  light_novel         301     0.006701
# 477              254997          13.0  light_novel         478     0.002859
# 369              276158          13.0  light_novel         370     0.003376
# 294              358334          12.0  light_novel         295     0.003445
# 489              242667          12.0  light_novel         490     0.001811
# 1396              52051          25.0         game        1397     0.010962
# 195              435627          25.0        manga         196     0.009441
# 605              172323          12.0  light_novel         606     0.002550
# 68               901879          25.0  light_novel          69     0.017465
#
#         rank rating                                             genres  \
# 33    5510.0  pg_13  ['Action', 'Adventure', 'Fantasy', 'Love Polyg...
# 261   7433.0  pg_13            ['Comedy', 'Drama', 'Ecchi', 'Romance']
# 1128  4486.0  pg_13                              ['Mystery', 'Sci-Fi']
# 606    984.0  pg_13  ['Comedy', 'Ecchi', 'Harem', 'Otaku Culture', ...
# 928   3467.0  pg_13  ['Adventure', 'Comedy', 'Mystery', 'Supernatur...
# 300   1775.0  pg_13  ['Comedy', 'Ecchi', 'Harem', 'Otaku Culture', ...
# 477   4305.0  pg_13             ['Comedy', 'Otaku Culture', 'Romance']
# 369   4306.0  pg_13           ['Comedy', 'Harem', 'Romance', 'School']
# 294   4841.0  pg_13  ['Action', 'Comedy', 'Ecchi', 'Fantasy', 'Hare...
# 489   4018.0  pg_13  ['Action', 'Comedy', 'Ecchi', 'Fantasy', 'Hare...
# 1396  1373.0  pg_13     ['Comedy', 'Drama', 'Idols (Female)', 'Music']
# 195    318.0  pg_13      ['Action', 'Adventure', 'Fantasy', 'Shounen']
# 605   3075.0  pg_13  ['Comedy', 'Fantasy', 'Harem', 'Isekai', 'Otak...
# 68     597.0  pg_13  ['Action', 'Adventure', 'Drama', 'Fantasy', 'I...
#
#                 studios                                           synopsis  \
# 33     ['A-1 Pictures']  A year after escaping Sword Art Online, Kazuto...
# 261    ['A-1 Pictures']  One year ago, Sagiri Izumi became step-sibling...
# 1128   ['A-1 Pictures']  A blog disproving the supernatural, co-run by ...
# 606    ['A-1 Pictures']  After finally completing the first route of hi...
# 928    ['A-1 Pictures']  Nanae Island is a man-made island in the Pacif...
# 300    ['A-1 Pictures']  Tomoya Aki, an otaku, has been obsessed with c...
# 477    ['A-1 Pictures']  The diehard otaku Kirino Kousaka has returned ...
# 369    ['A-1 Pictures']  The infidelity of Eita Kidou's parents not onl...
# 294    ['A-1 Pictures']  In the previous century, an unprecedented disa...
# 489    ['A-1 Pictures']  Gakusen Toshi Asterisk 2nd Season continues th...
# 1396   ['A-1 Pictures']  765 Production Studio manages the unique talen...
# 195    ['A-1 Pictures']  After celebrating their victory against Al-Tha...
# 605           ['feel.']  Shinichi Kanou is a shut-in otaku with a vast ...
# 68    ['Kinema Citrus']  The Four Cardinal Heroes are a group of ordina...
#
#        nsfw
# 33    white
# 261   white
# 1128  white
# 606   white
# 928   white
# 300   white
# 477   white
# 369   white
# 294   white
# 489   white
# 1396  white
# 195   white
# 605   white
# 68    white

# %% [markdown]
# ### Similarity Analysis Using The String Features

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
# import sweetviz as sv
# #You could specify which variable in your dataset is the target for your model creation. We can specify it using the target_feat parameter.
# data_report = sv.analyze(data)

# %%
# data_report.show_notebook(w=1500, h=900, scale=0.8)
# data_report.show_html(scale=0.9)

# %% [markdown]
# ### **Cos-similarity | TFIDF:**

# %%
tfidf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(data['synopsis'] + data['genres'] + data['rating'] + data['studios']+data['type'])
tfidf_matrix.shape

# %% [markdown]
# Using the Cosine Similarity to calculate a numeric quantity that denotes the similarity between two movies.
#
# $cosine(x,y) = \frac{x. y^\intercal}{||x||.||y||}$

# %%
cos_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
data = data.reset_index()
titles = data['title']
indices = pd.Series(data.index, index=data['title'])

# %%
def get_recommendations(title):
    idx = indices[title]
    sim_scores = list(enumerate(cos_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    anime_indices = [i[0] for i in sim_scores]
    return titles.iloc[anime_indices]
data['title'][3]

# %%
cos_results=get_recommendations('Death Note').head(10)
cos_results

# %% [markdown]
# Not so close recommendations but good start

# %% [markdown]
# **zenzen wakaranaaaaaiiiii !!!!!!!!!!!!!** </br>
# :"D </br>
# pair-wise distance results not related to cosine Similarity results at all no intersections. </br>
# using keywords or using Full synopsis didn't matter for cos similarity so better for resources use keywords

# %% [markdown]
# ### **RecommendNet Maybe?** :

# %% [markdown]
# **Zenzen heiki janai :"D , Tasukete, Dare ka tasukeeteeeeee !** <br />
#   Aug 2022 Work

# %% [markdown]
# #### *Normal Recommender features*

# %%
# Callbacks
from tensorflow.python.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005
batch_size = 10000
rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=0)

checkpoint_filepath = './weights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                            save_weights_only=True,
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True)

early_stopping = EarlyStopping(patience = 3, monitor='val_loss', 
                            mode='min', restore_best_weights=True)

my_callbacks = [
    model_checkpoints,
    lr_callback,
    early_stopping,   
]

# %%
print(len(X_test_array[0]))
print(len(y_test))

# %%
# Model training
history = model1.fit(
    x=X_train_array,
    y=y_train,
    batch_size=batch_size,
    epochs=20,
    verbose=1,
    validation_data=(X_test_array, y_test),
    callbacks=my_callbacks
)

model1.load_weights(checkpoint_filepath)

# %%
#Training results
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history["loss"][0:-2])
plt.plot(history.history["val_loss"][0:-2])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
from tqdm.keras import TqdmCallback


history = model1.fit(
    x=X_train_array,
    y=y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(X_test_array, y_test),
    verbose = 0, 
    callbacks=[TqdmCallback(verbose=0)])

model1.load_weights(checkpoint_filepath)

# %%
#Training results
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(history.history["loss"][0:-2])
plt.plot(history.history["val_loss"][0:-2])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
def extract_weights(name, model):
    weight_layer = model.get_layer(name)
    weights = weight_layer.get_weights()[0]
    weights = weights / np.linalg.norm(weights, axis = 1).reshape((-1, 1))
    return weights

anime_weights = extract_weights('anime_embedding', model1)
user_weights = extract_weights('user_embedding', model1)

# %%
data.columns

# %%
name = data[data.id == 100].title.values[0]
print(name)

# %%
# Fixing Names
def get_animename(anime_id):
    try:
        name = data[data.id == anime_id].title.values[0]
        return name
    except:
        print('error')
        return 0

data["eng_version"] = data['title']


data.sort_values(by=['mean'], 
                inplace=True,
                ascending=False, 
                kind='quicksort',
                na_position='last')

df = data[["id","title", "mean", "genres", "num_episodes", 
        "type","synopsis"]]


def get_animeframe(anime):
    if isinstance(anime, int):
        return df[df.id == anime]
    if isinstance(anime, str):
        return df[df.title == anime]
def get_sypnopsis(anime):
    if isinstance(anime, int):
        return df[df.id == anime].synopsis.values[0]

# %%
df.shape

# %%
pd.set_option("max_colwidth", None)

def find_similar_animes(name, n, return_dist=False, neg=False):
        index = get_animeframe(name).id.values[0]
        print(index)
        encoded_index = anime2anime_encoded.get(index)
        weights = anime_weights
        print(encoded_index)
        dists = np.dot(weights, weights[encoded_index])
        sorted_dists = np.argsort(dists)
        
        n = n + 1            
        
        if neg:
            closest = sorted_dists[:n]
        else:
            closest = sorted_dists[-n:]
        print('animes closest to {}'.format(name))
        if return_dist:
            return dists, closest
        rindex = df
        similarityarr = []
        for close in closest:
            decoded_id = anime_encoded2anime.get(close)
            sypnopsis = get_sypnopsis(decoded_id)
            anime_frame = get_animeframe(decoded_id)
            anime_name = anime_frame.title.values[0]
            genre = anime_frame.genres.values[0]
            similarity = dists[close]
            similarityarr.append({"id": decoded_id, "title": anime_name,
                            "similarity": similarity,"genres": genre,
                            'synopsis': sypnopsis})
        frame = pd.Dataframe(similarityarr).sort_values(by="similarity", ascending=False)
        return frame[frame.id != index].drop(['id'], axis=1)

# %%
find_similar_animes('Death Note', n=10, neg=False)

# %% [markdown]
# #### *Features modding* <br />
#    Modifying parameters for Recommend NET

# %%
# dfdl =pd.DataFrame()

# %%
# dfdl_ids = data["id"].tolist()
# dfdlid_encoded = {x: i for i, x in enumerate(dfdl_ids)}
# n_animes = len(dfdlid_encoded)
# id_encoded2id = {i: x for i, x in enumerate(dfdl_ids)}
# dfdl["id"] = data["id"].map(dfdlid_encoded)

# dfdl_mean = data["mean"].tolist()
# dfdl_mean_encoded = {x: i for i, x in enumerate(dfdl_mean)}
# mean_encoded2mean = {i: x for i, x in enumerate(dfdl_mean)}
# n_users = len(dfdl_mean_encoded)
# dfdl["mean"] = data["mean"].map(dfdl_mean_encoded)

# dfdl_pop = data["popularity"].tolist()
# user2user_encoded = {x: i for i, x in enumerate(dfdl_pop)}
# user_encoded2user = {i: x for i, x in enumerate(dfdl_pop)}
# n_users = len(user2user_encoded)
# dfdl["popularity"] = data["popularity"].map(user2user_encoded)

# %%
data.columns, data.shape

# %%
# x1 = rdf[['user', 'anime']].values 

# #x2=  data[['id'],['popularity']].values
# x3=data[['mean'],['num_scoring_users']].values
# x4=data['rank'].tolist(),data['num_favorites'].tolist()
# x5= df.filter(regex='^type_',axis=1).values[i]
# x6= df.filter(regex='^source_',axis=1).values[i]

# y = rdf["rating"]
# # Split
# test_set_size = 250000 #10k for test set
# train_indices = rdf_sampled.shape[0] - test_set_size 
# len(x1),len(x2),len(x2[1]),len(x3),len(x3[1]),len(x4),len(x4[1]),len(y),

# %%
# X3= x3[:,0] + x3[:,2] +x3[:,3] + x3[:,4] + x3[:,5] + x3[:,1] 
# X4=['None']*len(x4)*len(x4[1])
# for i in range(len(x4[1])):
#     X4 =X4 + x4[:,i]

# %%
# X1_train, X1_test, y_train, y_test = (
#     x1[:train_indices],
#     x1[train_indices:],
#     y[:train_indices],
#     y[train_indices:],
# )

# %% [markdown]
# ### *After Reading Some Articels:*

# %% [markdown]
# #### **Research at home** <br />
#    Dec. 2022 work <br />
#
# Semantic Similarity on synopsis using nlp models.

# %% [markdown]
# Potential Models for learning: <br />
# * paraphrase-miniLM
# * stsb-roberta latest alternatives
# * bert-base-nli-mean-tokens

# %% [markdown]
# **To_Do:**
# - Get embeddings from pretrained for all synopsis ( all paragraphs ).
# - Compare Similarity using distance wise / cosine / pairwise whatever the hell will measure similarity of embeddings.
# - Worst case senario ,(For each sentence embeddings in the requested anime synopsis loop cosine similarity between all sentences in all other synopsis)
# - Optimization worth testing: Finding similarity between sentences in the same synopsis to get unique sentences and store those while ignoring sentences that are pretty much similar in embeddings, that leads to having smaller group of sentences for each synopsis to loop on (Still looping bratan).
# - 5Head IDEA: Semantic Keyword embeddings similarity analysis to get potential chosen titles to do semantic sentence analysis on.
# - **OR JUST USE PARAPHRASE MINING U Fokin IDIOT, anata BAKA ??? hontoni BAKAAAA.**

# %% [markdown]
# ## *Using Synopsis NLP:*

# %%
import torch
import tensorflow as tf
import tensorflow_hub as hub

# Load the pre-trained Universal Sentence Encoder
model = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Load your dataset into a pandas DataFrame
df = pd.read_csv("your_dataset.csv")

# Encode each paragraph in the "description" column using the pre-trained Universal Sentence Encoder
inputs = model(df['description'].tolist()).numpy()

# Convert the encoding vectors to a PyTorch tensor
inputs = torch.from_numpy(inputs)

# Calculate the cosine similarity between each pair of vectors
similarity = torch.nn.functional.cosine_similarity(inputs, inputs, dim=-1)

# For each paragraph, find the indices of the top k most similar paragraphs
k = 10  # number of similar paragraphs to find
top_k, indices = torch.topk(similarity, k, dim=-1)

# Create a new column in the pandas DataFrame to store the top k similar paragraphs
df['similar_paragraphs'] = [list(row) for row in indices]
